# %%
import json
from collections import defaultdict

f = open('../2021Games/game5.json')

data = json.load(f)

f.close()
data
# Out:
# {'id': '3475723e-bc6f-46c3-88f4-134cc34f1f4a',
#  'status': 'closed',
#  'scheduled': '2021-10-10T17:00:00+00:00',
#  'attendance': 68450,
#  'entry_mode': 'LDE',
#  'clock': '00:00',
#  'quarter': 4,
#  'sr_id': 'sr:match:27305900',
#  'weather': {'condition': 'Partly cloudy',
#   'humidity': 75,
#   'temp': 84,
#   'wind': {'speed': 19, 'direction': 'SSE'}},
#  'summary': {'season': {'id': '06275f0f-08ff-4787-91fc-5c30464ccfd9',
#    'year': 2021,
#    'type': 'REG',
#    'name': 'REG'},
#   'week': {'id': 'fbc9b693-f6db-495b-a41f-a8a3686363c3',
#    'sequence': 5,
#    'title': '5'},
#   'venue': {'id': '6a72e5ca-33d0-40af-8e6b-b32a4d3d9346',
#    'name': 'NRG Stadium',
#    'city': 'Houston',
#    'state': 'TX',
#    'country': 'USA',
#    'zip': '77054',
#    'address': 'One Reliant Park',
#    'capacity': 72220,
#    'surface': 'artificial',
#    'roof_type': 'retractable_dome',
#    'sr_id': 'sr:venue:2402',
#    'location': {'lat': '29.684735', 'lng': '-95.410725'}},
#   'home': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#    'name': 'Texans',
#    'market': 'Houston',
#    'alias': 'HOU',
#    'sr_id': 'sr:competitor:4324',
#    'used_timeouts': 3,
#    'remaining_timeouts': 0,
#    'points': 22,
#    'used_challenges': 0,
#    'remaining_challenges': 2,
#    'record': {'wins': 4, 'losses': 13, 'ties': 0}},
#   'away': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#    'name': 'Patriots',
#    'market': 'New England',
#    'alias': 'NE',
#    'sr_id': 'sr:competitor:4424',
#    'used_timeouts': 2,
#    'remaining_timeouts': 1,
#    'points': 25,
#    'used_challenges': 0,
#    'remaining_challenges': 2,
#    'record': {'wins': 10, 'losses': 7, 'ties': 0}}},
#  'periods': [{'period_type': 'quarter',
#    'id': '40471763-7b35-40e9-8467-181dc99117a9',
#    'number': 1,
#    'sequence': 1,
#    'scoring': {'home': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#      'name': 'Texans',
#      'market': 'Houston',
#      'alias': 'HOU',
#      'sr_id': 'sr:competitor:4324',
#      'points': 6},
#     'away': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#      'name': 'Patriots',
#      'market': 'New England',
#      'alias': 'NE',
#      'sr_id': 'sr:competitor:4424',
#      'points': 0}},
#    'coin_toss': {'home': {'outcome': 'lost',
#      'decision': 'receive',
#      'direction': 'south'},
#     'away': {'outcome': 'won', 'decision': 'defer', 'direction': 'south'}},
#    'pbp': [{'type': 'drive',
#      'id': '78f7e42c-84e3-4b41-ae01-34616a11efc2',
#      'sequence': 1,
#      'start_reason': 'Kickoff',
#      'end_reason': 'Touchdown',
#      'play_count': 18,
#      'duration': '10:06',
#      'first_downs': 6,
#      'gain': 79,
#      'penalty_yards': 0,
#      'inside_20': True,
#      'scoring_drive': True,
#      'created_at': '2021-10-10T17:03:16+00:00',
#      'updated_at': '2021-10-10T17:18:25+00:00',
#      'events': [{'type': 'play',
#        'id': 'bbce21d0-29e9-11ec-834e-9dfff327683a',
#        'sequence': 1633885395482.0,
#        'clock': '15:00',
#        'home_points': 0,
#        'away_points': 0,
#        'play_type': 'kickoff',
#        'wall_clock': '2021-10-10T17:02:41+00:00',
#        'description': 'J.Bailey kicks 68 yards from NE 35 to the HOU End Zone. A.Roberts returns the kickoff. Tackled by C.Winovich at HOU 21.',
#        'fake_punt': False,
#        'fake_field_goal': False,
#        'screen_pass': False,
#        'hash_mark': 'Middle',
#        'play_action': False,
#        'run_pass_option': False,
#        'created_at': '2021-10-10T17:03:15+00:00',
#        'updated_at': '2021-10-11T15:44:54+00:00',
#        'start_situation': {'clock': '15:00',
#         'down': 0,
#         'yfd': 0,
#         'possession': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#          'name': 'Patriots',
#          'market': 'New England',
#          'alias': 'NE',
#          'sr_id': 'sr:competitor:4424'},
#         'location': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#          'name': 'Patriots',
#          'market': 'New England',
#          'alias': 'NE',
#          'sr_id': 'sr:competitor:4424',
#          'yardline': 35}},
#        'end_situation': {'clock': '14:55',
#         'down': 1,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 21}},
#        'statistics': [{'stat_type': 'kick',
#          'attempt': 1,
#          'yards': 68,
#          'net_yards': 44,
#          'endzone': 1,
#          'onside_attempt': 0,
#          'onside_success': 0,
#          'squib_kick': 0,
#          'player': {'id': 'af1335c6-c262-4488-9352-86ba80754583',
#           'name': 'Jake Bailey',
#           'jersey': '07',
#           'position': 'P',
#           'sr_id': 'sr:player:1767650'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}},
#         {'stat_type': 'return',
#          'return': 1,
#          'yards': 24,
#          'category': 'kick_return',
#          'player': {'id': '9691f874-be36-4529-a7eb-dde22ee4a848',
#           'name': 'Andre Roberts',
#           'jersey': '19',
#           'position': 'WR',
#           'sr_id': 'sr:player:830167'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'defense',
#          'tackle': 1,
#          'category': 'special_team',
#          'missed_tackles': 0,
#          'def_target': 0,
#          'def_comp': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'batted_pass': 0,
#          'player': {'id': '5d235c9b-8d01-44a7-a3ec-b5c7bd4491ee',
#           'name': 'Chase Winovich',
#           'jersey': '50',
#           'position': 'DE',
#           'sr_id': 'sr:player:1218664'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}}],
#        'details': [{'category': 'kick_off',
#          'description': 'J.Bailey kicks 68 yards from NE 35 to the HOU End Zone.',
#          'sequence': 0,
#          'yards': 68,
#          'result': 'returned',
#          'start_location': {'alias': 'NE', 'yardline': 35},
#          'end_location': {'alias': 'HOU', 'yardline': -3},
#          'players': [{'id': 'af1335c6-c262-4488-9352-86ba80754583',
#            'name': 'Jake Bailey',
#            'jersey': '07',
#            'position': 'P',
#            'sr_id': 'sr:player:1767650',
#            'role': 'kick'}]},
#         {'category': 'kick_off_return',
#          'description': 'A.Roberts returns the kickoff.',
#          'sequence': 1,
#          'yards': 24,
#          'result': 'tackled',
#          'start_location': {'alias': 'HOU', 'yardline': -3},
#          'end_location': {'alias': 'HOU', 'yardline': 21},
#          'players': [{'id': 'af1335c6-c262-4488-9352-86ba80754583',
#            'name': 'Jake Bailey',
#            'jersey': '07',
#            'position': 'P',
#            'sr_id': 'sr:player:1767650',
#            'role': 'kick'},
#           {'id': '9691f874-be36-4529-a7eb-dde22ee4a848',
#            'name': 'Andre Roberts',
#            'jersey': '19',
#            'position': 'WR',
#            'sr_id': 'sr:player:830167',
#            'role': 'return'}]},
#         {'category': 'tackle',
#          'description': 'Tackled by C.Winovich at HOU 21.',
#          'sequence': 2,
#          'start_location': {'alias': 'HOU', 'yardline': 21},
#          'end_location': {'alias': 'HOU', 'yardline': 21},
#          'players': [{'id': '5d235c9b-8d01-44a7-a3ec-b5c7bd4491ee',
#            'name': 'Chase Winovich',
#            'jersey': '50',
#            'position': 'DE',
#            'sr_id': 'sr:player:1218664',
#            'role': 'tackle'}]}]},
#       {'type': 'play',
#        'id': 'fe84c450-29eb-11ec-834e-9dfff327683a',
#        'sequence': 1633885440526.0,
#        'clock': '14:55',
#        'home_points': 0,
#        'away_points': 0,
#        'play_type': 'rush',
#        'wall_clock': '2021-10-10T17:03:43+00:00',
#        'description': 'M.Ingram rushed right guard to HOU 29 for 8 yards. Tackled by J.Bentley, J.Jackson at HOU 29.',
#        'men_in_box': 6,
#        'fake_punt': False,
#        'fake_field_goal': False,
#        'screen_pass': False,
#        'blitz': False,
#        'play_direction': 'Middle',
#        'left_tightends': 0,
#        'right_tightends': 1,
#        'hash_mark': 'Left Hash',
#        'qb_at_snap': 'Under Center',
#        'huddle': 'Huddle',
#        'running_lane': 4,
#        'play_action': False,
#        'run_pass_option': False,
#        'created_at': '2021-10-10T17:04:00+00:00',
#        'updated_at': '2021-10-11T15:47:25+00:00',
#        'start_situation': {'clock': '14:55',
#         'down': 1,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 21}},
#        'end_situation': {'clock': '14:20',
#         'down': 2,
#         'yfd': 2,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 29}},
#        'statistics': [{'stat_type': 'rush',
#          'attempt': 1,
#          'yards': 8,
#          'firstdown': 0,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'broken_tackles': 0,
#          'kneel_down': 0,
#          'scramble': 0,
#          'yards_after_contact': 4,
#          'player': {'id': 'f336567d-44a9-4245-8452-1dd485fd70fb',
#           'name': 'Mark Ingram II',
#           'jersey': '02',
#           'position': 'RB',
#           'sr_id': 'sr:player:827947'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'defense',
#          'tackle': 1,
#          'category': 'defense',
#          'missed_tackles': 0,
#          'def_target': 0,
#          'def_comp': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'batted_pass': 0,
#          'player': {'id': '3164fc4b-b2ae-43b3-9ff1-1d5f744b9f88',
#           'name': "Ja'Whaun Bentley",
#           'jersey': '08',
#           'position': 'LB',
#           'sr_id': 'sr:player:1227326'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}},
#         {'stat_type': 'defense',
#          'ast_tackle': 1,
#          'category': 'defense',
#          'missed_tackles': 0,
#          'def_target': 0,
#          'def_comp': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'batted_pass': 0,
#          'player': {'id': 'b590479c-79df-4505-be19-b0838574b434',
#           'name': 'J.C. Jackson',
#           'jersey': '27',
#           'position': 'DB',
#           'sr_id': 'sr:player:1474652'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}}],
#        'details': [{'category': 'rush',
#          'description': 'M.Ingram rushed right guard to HOU 29 for 8 yards.',
#          'sequence': 0,
#          'direction': 'right guard',
#          'yards': 8,
#          'result': 'tackled',
#          'start_location': {'alias': 'HOU', 'yardline': 21},
#          'end_location': {'alias': 'HOU', 'yardline': 29},
#          'players': [{'id': 'f336567d-44a9-4245-8452-1dd485fd70fb',
#            'name': 'Mark Ingram II',
#            'jersey': '02',
#            'position': 'RB',
#            'sr_id': 'sr:player:827947',
#            'role': 'rush'}]},
#         {'category': 'tackle',
#          'description': 'Tackled by J.Bentley, J.Jackson at HOU 29.',
#          'sequence': 1,
#          'start_location': {'alias': 'HOU', 'yardline': 29},
#          'end_location': {'alias': 'HOU', 'yardline': 29},
#          'players': [{'id': '3164fc4b-b2ae-43b3-9ff1-1d5f744b9f88',
#            'name': "Ja'Whaun Bentley",
#            'jersey': '08',
#            'position': 'LB',
#            'sr_id': 'sr:player:1227326',
#            'role': 'tackle'},
#           {'id': 'b590479c-79df-4505-be19-b0838574b434',
#            'name': 'J.C. Jackson',
#            'jersey': '27',
#            'position': 'DB',
#            'sr_id': 'sr:player:1474652',
#            'role': 'ast_tackle'}]}]},
#       {'type': 'play',
#        'id': '10ddba30-29ec-11ec-834e-9dfff327683a',
#        'sequence': 1633885469519.0,
#        'clock': '14:20',
#        'home_points': 0,
#        'away_points': 0,
#        'play_type': 'rush',
#        'wall_clock': '2021-10-10T17:04:19+00:00',
#        'description': 'M.Ingram rushed right end to HOU 30 for 1 yards. Tackled by K.Dugger; M.Judon at HOU 30.',
#        'men_in_box': 7,
#        'fake_punt': False,
#        'fake_field_goal': False,
#        'screen_pass': False,
#        'blitz': False,
#        'play_direction': 'Right',
#        'left_tightends': 1,
#        'right_tightends': 1,
#        'hash_mark': 'Middle',
#        'qb_at_snap': 'Under Center',
#        'huddle': 'Huddle',
#        'running_lane': 8,
#        'play_action': False,
#        'run_pass_option': False,
#        'created_at': '2021-10-10T17:04:29+00:00',
#        'updated_at': '2021-10-11T15:48:42+00:00',
#        'start_situation': {'clock': '14:20',
#         'down': 2,
#         'yfd': 2,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 29}},
#        'end_situation': {'clock': '13:43',
#         'down': 3,
#         'yfd': 1,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 30}},
#        'statistics': [{'stat_type': 'rush',
#          'attempt': 1,
#          'yards': 1,
#          'firstdown': 0,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'broken_tackles': 0,
#          'kneel_down': 0,
#          'scramble': 0,
#          'yards_after_contact': 1,
#          'player': {'id': 'f336567d-44a9-4245-8452-1dd485fd70fb',
#           'name': 'Mark Ingram II',
#           'jersey': '02',
#           'position': 'RB',
#           'sr_id': 'sr:player:827947'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'defense',
#          'ast_tackle': 1,
#          'category': 'defense',
#          'missed_tackles': 0,
#          'def_target': 0,
#          'def_comp': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'batted_pass': 0,
#          'player': {'id': '99d79bb9-45aa-4c64-99aa-a92ba2c278af',
#           'name': 'Matt Judon',
#           'jersey': '09',
#           'position': 'LB',
#           'sr_id': 'sr:player:1074196'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}},
#         {'stat_type': 'defense',
#          'ast_tackle': 1,
#          'category': 'defense',
#          'missed_tackles': 0,
#          'def_target': 0,
#          'def_comp': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'batted_pass': 0,
#          'player': {'id': '1d8d5c04-15e7-4346-9d1f-f128e4df3adb',
#           'name': 'Kyle Dugger',
#           'jersey': '23',
#           'position': 'DB',
#           'sr_id': 'sr:player:2040541'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}}],
#        'details': [{'category': 'rush',
#          'description': 'M.Ingram rushed right end to HOU 30 for 1 yards.',
#          'sequence': 0,
#          'direction': 'right end',
#          'yards': 1,
#          'result': 'tackled',
#          'start_location': {'alias': 'HOU', 'yardline': 29},
#          'end_location': {'alias': 'HOU', 'yardline': 30},
#          'players': [{'id': 'f336567d-44a9-4245-8452-1dd485fd70fb',
#            'name': 'Mark Ingram II',
#            'jersey': '02',
#            'position': 'RB',
#            'sr_id': 'sr:player:827947',
#            'role': 'rush'}]},
#         {'category': 'tackle',
#          'description': 'Tackled by K.Dugger; M.Judon at HOU 30.',
#          'sequence': 1,
#          'start_location': {'alias': 'HOU', 'yardline': 30},
#          'end_location': {'alias': 'HOU', 'yardline': 30},
#          'players': [{'id': '1d8d5c04-15e7-4346-9d1f-f128e4df3adb',
#            'name': 'Kyle Dugger',
#            'jersey': '23',
#            'position': 'DB',
#            'sr_id': 'sr:player:2040541',
#            'role': 'ast_tackle'},
#           {'id': '99d79bb9-45aa-4c64-99aa-a92ba2c278af',
#            'name': 'Matt Judon',
#            'jersey': '09',
#            'position': 'LB',
#            'sr_id': 'sr:player:1074196',
#            'role': 'ast_tackle'}]}]},
#       {'type': 'play',
#        'id': '21f619c0-29ec-11ec-834e-9dfff327683a',
#        'sequence': 1633885512690.0,
#        'clock': '13:43',
#        'home_points': 0,
#        'away_points': 0,
#        'play_type': 'rush',
#        'wall_clock': '2021-10-10T17:04:56+00:00',
#        'description': 'M.Ingram rushed left guard to HOU 31 for 1 yards. Tackled by D.Hightower; K.Dugger at HOU 31.',
#        'men_in_box': 8,
#        'fake_punt': False,
#        'fake_field_goal': False,
#        'screen_pass': False,
#        'blitz': False,
#        'play_direction': 'Middle',
#        'left_tightends': 1,
#        'right_tightends': 1,
#        'hash_mark': 'Right Hash',
#        'qb_at_snap': 'Under Center',
#        'huddle': 'Huddle',
#        'running_lane': 3,
#        'play_action': False,
#        'run_pass_option': False,
#        'created_at': '2021-10-10T17:05:12+00:00',
#        'updated_at': '2021-10-11T15:50:06+00:00',
#        'start_situation': {'clock': '13:43',
#         'down': 3,
#         'yfd': 1,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 30}},
#        'end_situation': {'clock': '13:00',
#         'down': 1,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 31}},
#        'statistics': [{'stat_type': 'rush',
#          'attempt': 1,
#          'yards': 1,
#          'firstdown': 1,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'broken_tackles': 0,
#          'kneel_down': 0,
#          'scramble': 0,
#          'yards_after_contact': 1,
#          'player': {'id': 'f336567d-44a9-4245-8452-1dd485fd70fb',
#           'name': 'Mark Ingram II',
#           'jersey': '02',
#           'position': 'RB',
#           'sr_id': 'sr:player:827947'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'defense',
#          'ast_tackle': 1,
#          'category': 'defense',
#          'missed_tackles': 0,
#          'def_target': 0,
#          'def_comp': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'batted_pass': 0,
#          'player': {'id': '1d8d5c04-15e7-4346-9d1f-f128e4df3adb',
#           'name': 'Kyle Dugger',
#           'jersey': '23',
#           'position': 'DB',
#           'sr_id': 'sr:player:2040541'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}},
#         {'stat_type': 'defense',
#          'ast_tackle': 1,
#          'category': 'defense',
#          'missed_tackles': 0,
#          'def_target': 0,
#          'def_comp': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'batted_pass': 0,
#          'player': {'id': 'e7a18744-0608-4118-888f-f51de5645ce9',
#           'name': "Dont'a Hightower",
#           'jersey': '54',
#           'position': 'LB',
#           'sr_id': 'sr:player:827685'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}},
#         {'stat_type': 'down_conversion',
#          'down': 3,
#          'attempt': 1,
#          'complete': 1,
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'first_down',
#          'category': 'rush',
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}}],
#        'details': [{'category': 'rush',
#          'description': 'M.Ingram rushed left guard to HOU 31 for 1 yards.',
#          'sequence': 0,
#          'direction': 'left guard',
#          'yards': 1,
#          'result': 'tackled',
#          'start_location': {'alias': 'HOU', 'yardline': 30},
#          'end_location': {'alias': 'HOU', 'yardline': 31},
#          'players': [{'id': 'f336567d-44a9-4245-8452-1dd485fd70fb',
#            'name': 'Mark Ingram II',
#            'jersey': '02',
#            'position': 'RB',
#            'sr_id': 'sr:player:827947',
#            'role': 'rush'}]},
#         {'category': 'tackle',
#          'description': 'Tackled by D.Hightower; K.Dugger at HOU 31.',
#          'sequence': 1,
#          'start_location': {'alias': 'HOU', 'yardline': 31},
#          'end_location': {'alias': 'HOU', 'yardline': 31},
#          'players': [{'id': 'e7a18744-0608-4118-888f-f51de5645ce9',
#            'name': "Dont'a Hightower",
#            'jersey': '54',
#            'position': 'LB',
#            'sr_id': 'sr:player:827685',
#            'role': 'ast_tackle'},
#           {'id': '1d8d5c04-15e7-4346-9d1f-f128e4df3adb',
#            'name': 'Kyle Dugger',
#            'jersey': '23',
#            'position': 'DB',
#            'sr_id': 'sr:player:2040541',
#            'role': 'ast_tackle'}]},
#         {'category': 'first_down',
#          'sequence': 2,
#          'result': 'rush',
#          'start_location': {'alias': 'HOU', 'yardline': 31},
#          'end_location': {'alias': 'HOU', 'yardline': 31},
#          'players': []},
#         {'category': 'third_down_conversion',
#          'sequence': 3,
#          'result': 'good',
#          'start_location': {'alias': 'HOU', 'yardline': 31},
#          'end_location': {'alias': 'HOU', 'yardline': 31},
#          'players': []}]},
#       {'type': 'play',
#        'id': '3bec10f0-29ec-11ec-834e-9dfff327683a',
#        'sequence': 1633885552811.0,
#        'clock': '13:00',
#        'home_points': 0,
#        'away_points': 0,
#        'play_type': 'rush',
#        'wall_clock': '2021-10-10T17:05:39+00:00',
#        'description': 'M.Ingram rushed right guard to HOU 33 for 2 yards. Tackled by J.Bentley; D.Wise at HOU 33.',
#        'men_in_box': 6,
#        'fake_punt': False,
#        'fake_field_goal': False,
#        'screen_pass': False,
#        'blitz': False,
#        'play_direction': 'Right',
#        'left_tightends': 0,
#        'right_tightends': 0,
#        'hash_mark': 'Right Hash',
#        'qb_at_snap': 'Shotgun',
#        'huddle': 'Huddle',
#        'running_lane': 4,
#        'play_action': False,
#        'run_pass_option': False,
#        'created_at': '2021-10-10T17:05:52+00:00',
#        'updated_at': '2021-10-11T15:53:03+00:00',
#        'start_situation': {'clock': '13:00',
#         'down': 1,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 31}},
#        'end_situation': {'clock': '12:20',
#         'down': 2,
#         'yfd': 8,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 33}},
#        'statistics': [{'stat_type': 'rush',
#          'attempt': 1,
#          'yards': 2,
#          'firstdown': 0,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'broken_tackles': 0,
#          'kneel_down': 0,
#          'scramble': 0,
#          'yards_after_contact': 2,
#          'player': {'id': 'f336567d-44a9-4245-8452-1dd485fd70fb',
#           'name': 'Mark Ingram II',
#           'jersey': '02',
#           'position': 'RB',
#           'sr_id': 'sr:player:827947'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'defense',
#          'ast_tackle': 1,
#          'category': 'defense',
#          'missed_tackles': 0,
#          'def_target': 0,
#          'def_comp': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'batted_pass': 0,
#          'player': {'id': '2516f9e7-9927-409d-adbe-b32d680ae71d',
#           'name': 'Deatrich Wise Jr.',
#           'jersey': '91',
#           'position': 'DE',
#           'sr_id': 'sr:player:1130123'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}},
#         {'stat_type': 'defense',
#          'ast_tackle': 1,
#          'category': 'defense',
#          'missed_tackles': 0,
#          'def_target': 0,
#          'def_comp': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'batted_pass': 0,
#          'player': {'id': '3164fc4b-b2ae-43b3-9ff1-1d5f744b9f88',
#           'name': "Ja'Whaun Bentley",
#           'jersey': '08',
#           'position': 'LB',
#           'sr_id': 'sr:player:1227326'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}}],
#        'details': [{'category': 'rush',
#          'description': 'M.Ingram rushed right guard to HOU 33 for 2 yards.',
#          'sequence': 0,
#          'direction': 'right guard',
#          'yards': 2,
#          'result': 'tackled',
#          'start_location': {'alias': 'HOU', 'yardline': 31},
#          'end_location': {'alias': 'HOU', 'yardline': 33},
#          'players': [{'id': 'f336567d-44a9-4245-8452-1dd485fd70fb',
#            'name': 'Mark Ingram II',
#            'jersey': '02',
#            'position': 'RB',
#            'sr_id': 'sr:player:827947',
#            'role': 'rush'}]},
#         {'category': 'tackle',
#          'description': 'Tackled by J.Bentley; D.Wise at HOU 33.',
#          'sequence': 1,
#          'start_location': {'alias': 'HOU', 'yardline': 33},
#          'end_location': {'alias': 'HOU', 'yardline': 33},
#          'players': [{'id': '3164fc4b-b2ae-43b3-9ff1-1d5f744b9f88',
#            'name': "Ja'Whaun Bentley",
#            'jersey': '08',
#            'position': 'LB',
#            'sr_id': 'sr:player:1227326',
#            'role': 'ast_tackle'},
#           {'id': '2516f9e7-9927-409d-adbe-b32d680ae71d',
#            'name': 'Deatrich Wise Jr.',
#            'jersey': '91',
#            'position': 'DE',
#            'sr_id': 'sr:player:1130123',
#            'role': 'ast_tackle'}]}]},
#       {'type': 'play',
#        'id': '6135a8d0-29ec-11ec-834e-9dfff327683a',
#        'sequence': 1633885584799.0,
#        'clock': '12:20',
#        'home_points': 0,
#        'away_points': 0,
#        'play_type': 'pass',
#        'wall_clock': '2021-10-10T17:06:19+00:00',
#        'description': 'D.Mills steps back to pass. D.Mills pass incomplete short left intended for P.Brown.',
#        'players_rushed': 4,
#        'men_in_box': 6,
#        'fake_punt': False,
#        'fake_field_goal': False,
#        'screen_pass': False,
#        'blitz': False,
#        'play_direction': 'Left Sideline',
#        'left_tightends': 0,
#        'right_tightends': 0,
#        'hash_mark': 'Right Hash',
#        'pocket_location': 'Middle',
#        'qb_at_snap': 'Shotgun',
#        'huddle': 'Huddle',
#        'pass_route': 'Flat',
#        'play_action': False,
#        'run_pass_option': False,
#        'created_at': '2021-10-10T17:06:24+00:00',
#        'updated_at': '2021-10-11T15:54:47+00:00',
#        'start_situation': {'clock': '12:20',
#         'down': 2,
#         'yfd': 8,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 33}},
#        'end_situation': {'clock': '12:15',
#         'down': 3,
#         'yfd': 8,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 33}},
#        'statistics': [{'stat_type': 'pass',
#          'attempt': 1,
#          'complete': 0,
#          'att_yards': 0,
#          'firstdown': 0,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'incompletion_type': 'Dropped Pass',
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'pocket_time': 1.473,
#          'on_target_throw': 1,
#          'batted_pass': 0,
#          'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#           'name': 'Davis Mills',
#           'jersey': '10',
#           'position': 'QB',
#           'sr_id': 'sr:player:2197842'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'receive',
#          'firstdown': 0,
#          'target': 1,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'dropped': 1,
#          'catchable': 1,
#          'player': {'id': '6733b953-de77-44e5-acbf-c2d3a0940243',
#           'name': 'Pharaoh Brown',
#           'jersey': '85',
#           'position': 'TE',
#           'sr_id': 'sr:player:1132467'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'defense',
#          'missed_tackles': 0,
#          'def_target': 1,
#          'def_comp': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'batted_pass': 0,
#          'player': {'id': '3164fc4b-b2ae-43b3-9ff1-1d5f744b9f88',
#           'name': "Ja'Whaun Bentley",
#           'jersey': '08',
#           'position': 'LB',
#           'sr_id': 'sr:player:1227326'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}}],
#        'details': [{'category': 'pass',
#          'description': 'D.Mills steps back to pass.',
#          'sequence': 0,
#          'start_location': {'alias': 'HOU', 'yardline': 33},
#          'end_location': {'alias': 'HOU', 'yardline': 33},
#          'players': [{'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#            'name': 'Davis Mills',
#            'jersey': '10',
#            'position': 'QB',
#            'sr_id': 'sr:player:2197842',
#            'role': 'pass'}]},
#         {'category': 'pass_incompletion',
#          'description': 'D.Mills pass incomplete short left intended for P.Brown.',
#          'sequence': 1,
#          'direction': 'short left',
#          'start_location': {'alias': 'HOU', 'yardline': 33},
#          'end_location': {'alias': 'HOU', 'yardline': 33},
#          'players': [{'id': '6733b953-de77-44e5-acbf-c2d3a0940243',
#            'name': 'Pharaoh Brown',
#            'jersey': '85',
#            'position': 'TE',
#            'sr_id': 'sr:player:1132467',
#            'role': 'receive'},
#           {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#            'name': 'Davis Mills',
#            'jersey': '10',
#            'position': 'QB',
#            'sr_id': 'sr:player:2197842',
#            'role': 'pass'}]}]},
#       {'type': 'play',
#        'id': '66aac110-29ec-11ec-834e-9dfff327683a',
#        'sequence': 1633885667335.0,
#        'clock': '12:15',
#        'home_points': 0,
#        'away_points': 0,
#        'play_type': 'pass',
#        'wall_clock': '2021-10-10T17:07:02+00:00',
#        'description': 'D.Mills steps back to pass. D.Mills pass incomplete short right intended for B.Cooks. PENALTY on NE-J.Jackson, Defensive Pass Interference, 10 yards, accepted. No Play.',
#        'fake_punt': False,
#        'fake_field_goal': False,
#        'screen_pass': False,
#        'play_action': False,
#        'run_pass_option': False,
#        'created_at': '2021-10-10T17:07:47+00:00',
#        'updated_at': '2021-10-10T17:08:13+00:00',
#        'start_situation': {'clock': '12:15',
#         'down': 3,
#         'yfd': 8,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 33}},
#        'end_situation': {'clock': '12:10',
#         'down': 1,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 43}},
#        'statistics': [{'stat_type': 'pass',
#          'nullified': True,
#          'attempt': 1,
#          'complete': 0,
#          'att_yards': 0,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'on_target_throw': 0,
#          'batted_pass': 0,
#          'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#           'name': 'Davis Mills',
#           'jersey': '10',
#           'position': 'QB',
#           'sr_id': 'sr:player:2197842'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'receive',
#          'nullified': True,
#          'target': 1,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'catchable': 0,
#          'player': {'id': 'b6b954eb-4591-4b7a-86b9-a481f15fdd58',
#           'name': 'Brandin Cooks',
#           'jersey': '13',
#           'position': 'WR',
#           'sr_id': 'sr:player:828495'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'penalty',
#          'penalty': 1,
#          'yards': 10,
#          'player': {'id': 'b590479c-79df-4505-be19-b0838574b434',
#           'name': 'J.C. Jackson',
#           'jersey': '27',
#           'position': 'DB',
#           'sr_id': 'sr:player:1474652'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}},
#         {'stat_type': 'first_down',
#          'category': 'penalty',
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}}],
#        'details': [{'category': 'pass',
#          'description': 'D.Mills steps back to pass.',
#          'sequence': 0,
#          'start_location': {'alias': 'HOU', 'yardline': 33},
#          'end_location': {'alias': 'HOU', 'yardline': 33},
#          'players': [{'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#            'name': 'Davis Mills',
#            'jersey': '10',
#            'position': 'QB',
#            'sr_id': 'sr:player:2197842',
#            'role': 'pass'}]},
#         {'category': 'pass_incompletion',
#          'description': 'D.Mills pass incomplete short right intended for B.Cooks.',
#          'sequence': 1,
#          'direction': 'short right',
#          'start_location': {'alias': 'HOU', 'yardline': 33},
#          'end_location': {'alias': 'HOU', 'yardline': 33},
#          'players': [{'id': 'b6b954eb-4591-4b7a-86b9-a481f15fdd58',
#            'name': 'Brandin Cooks',
#            'jersey': '13',
#            'position': 'WR',
#            'sr_id': 'sr:player:828495',
#            'role': 'receive'},
#           {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#            'name': 'Davis Mills',
#            'jersey': '10',
#            'position': 'QB',
#            'sr_id': 'sr:player:2197842',
#            'role': 'pass'}]},
#         {'category': 'penalty',
#          'description': 'PENALTY on NE-J.Jackson, Defensive Pass Interference, 10 yards, accepted.',
#          'sequence': 2,
#          'start_location': {'alias': 'HOU', 'yardline': 33},
#          'end_location': {'alias': 'HOU', 'yardline': 43},
#          'penalty': {'description': 'Defensive Pass Interference',
#           'result': 'accepted',
#           'yards': 10,
#           'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#            'name': 'Patriots',
#            'market': 'New England',
#            'alias': 'NE',
#            'sr_id': 'sr:competitor:4424'}},
#          'players': [{'id': 'b590479c-79df-4505-be19-b0838574b434',
#            'name': 'J.C. Jackson',
#            'jersey': '27',
#            'position': 'DB',
#            'sr_id': 'sr:player:1474652',
#            'role': 'penalty'}]},
#         {'category': 'no_play',
#          'description': 'No Play.',
#          'sequence': 3,
#          'start_location': {'alias': 'HOU', 'yardline': 43},
#          'end_location': {'alias': 'HOU', 'yardline': 43},
#          'players': []},
#         {'category': 'first_down',
#          'sequence': 4,
#          'result': 'penalty',
#          'start_location': {'alias': 'HOU', 'yardline': 43},
#          'end_location': {'alias': 'HOU', 'yardline': 43},
#          'players': []}]},
#       {'type': 'play',
#        'id': '97fe7860-29ec-11ec-834e-9dfff327683a',
#        'sequence': 1633885720187.0,
#        'clock': '12:10',
#        'home_points': 0,
#        'away_points': 0,
#        'play_type': 'rush',
#        'wall_clock': '2021-10-10T17:07:59+00:00',
#        'description': 'P.Lindsay rushed right guard to NE 47 for 10 yards. Pushed out of bounds by K.Dugger at NE 47. PENALTY on HOU-C.Moore, Offensive Holding, 10 yards, accepted.',
#        'men_in_box': 6,
#        'fake_punt': False,
#        'fake_field_goal': False,
#        'screen_pass': False,
#        'blitz': False,
#        'play_direction': 'Right',
#        'left_tightends': 0,
#        'right_tightends': 0,
#        'hash_mark': 'Right Hash',
#        'qb_at_snap': 'Shotgun',
#        'huddle': 'Huddle',
#        'running_lane': 4,
#        'play_action': False,
#        'run_pass_option': False,
#        'created_at': '2021-10-10T17:08:40+00:00',
#        'updated_at': '2021-10-11T15:57:25+00:00',
#        'start_situation': {'clock': '12:10',
#         'down': 1,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 43}},
#        'end_situation': {'clock': '8:17',
#         'down': 1,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 43}},
#        'statistics': [{'stat_type': 'rush',
#          'attempt': 1,
#          'yards': 10,
#          'firstdown': 0,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'broken_tackles': 0,
#          'kneel_down': 0,
#          'scramble': 0,
#          'yards_after_contact': 2,
#          'player': {'id': '8322b598-ab65-4b2c-8a54-af37f67a062d',
#           'name': 'Phillip Lindsay',
#           'jersey': '30',
#           'position': 'RB',
#           'sr_id': 'sr:player:1474840'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'penalty',
#          'penalty': 1,
#          'yards': 10,
#          'player': {'id': '0b504d67-639b-4ba8-979a-498a3086257b',
#           'name': 'Chris Moore',
#           'jersey': '15',
#           'position': 'WR',
#           'sr_id': 'sr:player:988781'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'defense',
#          'tackle': 1,
#          'category': 'defense',
#          'missed_tackles': 0,
#          'def_target': 0,
#          'def_comp': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'batted_pass': 0,
#          'player': {'id': '1d8d5c04-15e7-4346-9d1f-f128e4df3adb',
#           'name': 'Kyle Dugger',
#           'jersey': '23',
#           'position': 'DB',
#           'sr_id': 'sr:player:2040541'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}}],
#        'details': [{'category': 'rush',
#          'description': 'P.Lindsay rushed right guard to NE 47 for 10 yards.',
#          'sequence': 0,
#          'direction': 'right guard',
#          'yards': 10,
#          'result': 'tackled',
#          'start_location': {'alias': 'HOU', 'yardline': 43},
#          'end_location': {'alias': 'NE', 'yardline': 47},
#          'players': [{'id': '8322b598-ab65-4b2c-8a54-af37f67a062d',
#            'name': 'Phillip Lindsay',
#            'jersey': '30',
#            'position': 'RB',
#            'sr_id': 'sr:player:1474840',
#            'role': 'rush'}]},
#         {'category': 'pushed_out_of_bounds',
#          'description': 'Pushed out of bounds by K.Dugger at NE 47.',
#          'sequence': 1,
#          'start_location': {'alias': 'NE', 'yardline': 47},
#          'end_location': {'alias': 'NE', 'yardline': 47},
#          'players': [{'id': '1d8d5c04-15e7-4346-9d1f-f128e4df3adb',
#            'name': 'Kyle Dugger',
#            'jersey': '23',
#            'position': 'DB',
#            'sr_id': 'sr:player:2040541',
#            'role': 'tackle'}]},
#         {'category': 'penalty',
#          'description': 'PENALTY on HOU-C.Moore, Offensive Holding, 10 yards, accepted.',
#          'sequence': 2,
#          'start_location': {'alias': 'NE', 'yardline': 47},
#          'end_location': {'alias': 'HOU', 'yardline': 43},
#          'penalty': {'description': 'Offensive Holding',
#           'result': 'accepted',
#           'yards': 10,
#           'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#            'name': 'Texans',
#            'market': 'Houston',
#            'alias': 'HOU',
#            'sr_id': 'sr:competitor:4324'}},
#          'players': [{'id': '0b504d67-639b-4ba8-979a-498a3086257b',
#            'name': 'Chris Moore',
#            'jersey': '15',
#            'position': 'WR',
#            'sr_id': 'sr:player:988781',
#            'role': 'penalty'}]}]},
#       {'type': 'play',
#        'id': 'b77b1400-29ec-11ec-834e-9dfff327683a',
#        'sequence': 1633885760473.0,
#        'clock': '11:40',
#        'home_points': 0,
#        'away_points': 0,
#        'play_type': 'rush',
#        'wall_clock': '2021-10-10T17:09:10+00:00',
#        'description': 'M.Ingram rushed left guard to HOU 44 for 1 yards. Tackled by K.Van Noy at HOU 44.',
#        'men_in_box': 6,
#        'fake_punt': False,
#        'fake_field_goal': False,
#        'screen_pass': False,
#        'blitz': False,
#        'play_direction': 'Left',
#        'left_tightends': 0,
#        'right_tightends': 0,
#        'hash_mark': 'Right Hash',
#        'qb_at_snap': 'Shotgun',
#        'huddle': 'Huddle',
#        'running_lane': 3,
#        'play_action': False,
#        'run_pass_option': False,
#        'created_at': '2021-10-10T17:09:20+00:00',
#        'updated_at': '2021-10-11T15:59:01+00:00',
#        'start_situation': {'clock': '11:40',
#         'down': 1,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 43}},
#        'end_situation': {'clock': '11:00',
#         'down': 2,
#         'yfd': 9,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
# ...
#         'possession': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#          'name': 'Patriots',
#          'market': 'New England',
#          'alias': 'NE',
#          'sr_id': 'sr:competitor:4424'},
#         'location': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#          'name': 'Patriots',
#          'market': 'New England',
#          'alias': 'NE',
#          'sr_id': 'sr:competitor:4424',
#          'yardline': 35}},
#        'end_situation': {'clock': '00:15',
#         'down': 1,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 25}},
#        'statistics': [{'stat_type': 'kick',
#          'attempt': 1,
#          'yards': 65,
#          'net_yards': 40,
#          'touchback': 1,
#          'onside_attempt': 0,
#          'onside_success': 0,
#          'squib_kick': 0,
#          'player': {'id': 'af1335c6-c262-4488-9352-86ba80754583',
#           'name': 'Jake Bailey',
#           'jersey': '07',
#           'position': 'P',
#           'sr_id': 'sr:player:1767650'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}},
#         {'stat_type': 'return',
#          'touchback': 1,
#          'category': 'kick_return',
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}}],
#        'details': [{'category': 'kick_off',
#          'description': 'J.Bailey kicks 65 yards from NE 35 to the HOU End Zone.',
#          'sequence': 0,
#          'yards': 65,
#          'result': 'touchback',
#          'start_location': {'alias': 'NE', 'yardline': 35},
#          'end_location': {'alias': 'HOU', 'yardline': 0},
#          'players': [{'id': 'af1335c6-c262-4488-9352-86ba80754583',
#            'name': 'Jake Bailey',
#            'jersey': '07',
#            'position': 'P',
#            'sr_id': 'sr:player:1767650',
#            'role': 'kick'}]},
#         {'category': 'touchback',
#          'description': 'Touchback.',
#          'sequence': 1,
#          'result': 'touchback',
#          'start_location': {'alias': 'HOU', 'yardline': 0},
#          'end_location': {'alias': 'HOU', 'yardline': 25},
#          'players': [{'id': 'af1335c6-c262-4488-9352-86ba80754583',
#            'name': 'Jake Bailey',
#            'jersey': '07',
#            'position': 'P',
#            'sr_id': 'sr:player:1767650',
#            'role': 'kick'}]}]},
#       {'type': 'play',
#        'id': '7d7e2ea0-2a04-11ec-834e-9dfff327683a',
#        'sequence': 1633895982472.0,
#        'clock': '00:15',
#        'home_points': 22,
#        'away_points': 25,
#        'play_type': 'pass',
#        'wall_clock': '2021-10-10T19:59:26+00:00',
#        'description': 'D.Mills steps back to pass. D.Mills pass incomplete short left intended for.',
#        'players_rushed': 2,
#        'men_in_box': 2,
#        'fake_punt': False,
#        'fake_field_goal': False,
#        'screen_pass': False,
#        'blitz': False,
#        'play_direction': 'Left Sideline',
#        'left_tightends': 0,
#        'right_tightends': 0,
#        'hash_mark': 'Left Hash',
#        'pocket_location': 'Middle',
#        'qb_at_snap': 'Shotgun',
#        'huddle': 'Huddle',
#        'play_action': False,
#        'run_pass_option': False,
#        'created_at': '2021-10-10T19:59:42+00:00',
#        'updated_at': '2021-10-12T19:28:45+00:00',
#        'start_situation': {'clock': '00:15',
#         'down': 1,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 25}},
#        'end_situation': {'clock': '00:08',
#         'down': 2,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 25}},
#        'statistics': [{'stat_type': 'pass',
#          'attempt': 1,
#          'complete': 0,
#          'att_yards': 0,
#          'firstdown': 0,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'incompletion_type': 'Thrown Away',
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'pocket_time': 3.887,
#          'on_target_throw': 0,
#          'batted_pass': 0,
#          'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#           'name': 'Davis Mills',
#           'jersey': '10',
#           'position': 'QB',
#           'sr_id': 'sr:player:2197842'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}}],
#        'details': [{'category': 'pass',
#          'description': 'D.Mills steps back to pass.',
#          'sequence': 0,
#          'start_location': {'alias': 'HOU', 'yardline': 25},
#          'end_location': {'alias': 'HOU', 'yardline': 25},
#          'players': [{'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#            'name': 'Davis Mills',
#            'jersey': '10',
#            'position': 'QB',
#            'sr_id': 'sr:player:2197842',
#            'role': 'pass'}]},
#         {'category': 'pass_incompletion',
#          'description': 'D.Mills pass incomplete short left intended for.',
#          'sequence': 1,
#          'direction': 'short left',
#          'start_location': {'alias': 'HOU', 'yardline': 25},
#          'end_location': {'alias': 'HOU', 'yardline': 25},
#          'players': [{'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#            'name': 'Davis Mills',
#            'jersey': '10',
#            'position': 'QB',
#            'sr_id': 'sr:player:2197842',
#            'role': 'pass'}]}]},
#       {'type': 'play',
#        'id': '9c8943c0-2a04-11ec-834e-9dfff327683a',
#        'sequence': 1633896093966.0,
#        'clock': '00:08',
#        'home_points': 22,
#        'away_points': 25,
#        'play_type': 'pass',
#        'wall_clock': '2021-10-10T20:00:10+00:00',
#        'description': 'D.Mills pass short right complete to HOU 33. Catch made by C.Conley at HOU 33. Gain of 7 yards. C.Conley FUMBLES. Fumble RECOVERED by NE-M.Judon at HOU 47. Tackled by at NE 47. PENALTY on NE-J.Jackson, Defensive Illegal Blindside Block, 0 yards, accepted. ',
#        'players_rushed': 2,
#        'men_in_box': 2,
#        'fake_punt': False,
#        'fake_field_goal': False,
#        'screen_pass': False,
#        'blitz': False,
#        'play_direction': 'Right',
#        'left_tightends': 0,
#        'right_tightends': 0,
#        'hash_mark': 'Left Hash',
#        'pocket_location': 'Middle',
#        'qb_at_snap': 'Shotgun',
#        'huddle': 'Huddle',
#        'pass_route': 'Curl',
#        'play_action': False,
#        'run_pass_option': False,
#        'created_at': '2021-10-10T20:01:33+00:00',
#        'updated_at': '2021-11-02T19:02:46+00:00',
#        'start_situation': {'clock': '00:08',
#         'down': 2,
#         'yfd': 10,
#         'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 25}},
#        'end_situation': {'clock': '00:00',
#         'down': 1,
#         'yfd': 10,
#         'possession': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#          'name': 'Patriots',
#          'market': 'New England',
#          'alias': 'NE',
#          'sr_id': 'sr:competitor:4424'},
#         'location': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#          'name': 'Texans',
#          'market': 'Houston',
#          'alias': 'HOU',
#          'sr_id': 'sr:competitor:4324',
#          'yardline': 47}},
#        'statistics': [{'stat_type': 'pass',
#          'attempt': 1,
#          'complete': 1,
#          'yards': 7,
#          'att_yards': 8,
#          'firstdown': 0,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'blitz': 0,
#          'hurry': 0,
#          'knockdown': 0,
#          'pocket_time': 2.463,
#          'on_target_throw': 1,
#          'batted_pass': 0,
#          'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#           'name': 'Davis Mills',
#           'jersey': '10',
#           'position': 'QB',
#           'sr_id': 'sr:player:2197842'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'receive',
#          'firstdown': 0,
#          'target': 1,
#          'reception': 1,
#          'yards': 7,
#          'yards_after_catch': -1,
#          'inside_20': 0,
#          'goaltogo': 0,
#          'broken_tackles': 0,
#          'dropped': 0,
#          'catchable': 0,
#          'yards_after_contact': 0,
#          'player': {'id': 'bd01d907-cd57-48cb-9136-5692a4764a20',
#           'name': 'Chris Conley',
#           'jersey': '18',
#           'position': 'WR',
#           'sr_id': 'sr:player:834671'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'penalty',
#          'penalty': 1,
#          'yards': 0,
#          'player': {'id': 'b590479c-79df-4505-be19-b0838574b434',
#           'name': 'J.C. Jackson',
#           'jersey': '27',
#           'position': 'DB',
#           'sr_id': 'sr:player:1474652'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}},
#         {'stat_type': 'fumble',
#          'lost': 1,
#          'player': {'id': 'bd01d907-cd57-48cb-9136-5692a4764a20',
#           'name': 'Chris Conley',
#           'jersey': '18',
#           'position': 'WR',
#           'sr_id': 'sr:player:834671'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}},
#         {'stat_type': 'fumble',
#          'opp_rec': 1,
#          'opp_rec_yards': -6,
#          'play_category': 'defense',
#          'player': {'id': '99d79bb9-45aa-4c64-99aa-a92ba2c278af',
#           'name': 'Matt Judon',
#           'jersey': '09',
#           'position': 'LB',
#           'sr_id': 'sr:player:1074196'},
#          'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#           'name': 'Patriots',
#           'market': 'New England',
#           'alias': 'NE',
#           'sr_id': 'sr:competitor:4424'}},
#         {'stat_type': 'fumble',
#          'fumble': 1,
#          'forced': 0,
#          'player': {'id': 'bd01d907-cd57-48cb-9136-5692a4764a20',
#           'name': 'Chris Conley',
#           'jersey': '18',
#           'position': 'WR',
#           'sr_id': 'sr:player:834671'},
#          'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#           'name': 'Texans',
#           'market': 'Houston',
#           'alias': 'HOU',
#           'sr_id': 'sr:competitor:4324'}}],
#        'details': [{'category': 'pass_completion',
#          'description': 'D.Mills pass short right complete to HOU 33.',
#          'sequence': 0,
#          'direction': 'short right',
#          'yards': 7,
#          'start_location': {'alias': 'HOU', 'yardline': 25},
#          'end_location': {'alias': 'HOU', 'yardline': 33},
#          'players': [{'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#            'name': 'Davis Mills',
#            'jersey': '10',
#            'position': 'QB',
#            'sr_id': 'sr:player:2197842',
#            'role': 'pass'}]},
#         {'category': 'pass_reception',
#          'description': 'Catch made by C.Conley at HOU 33. Gain of 7 yards.',
#          'sequence': 1,
#          'yards': 7,
#          'result': 'fumbled',
#          'start_location': {'alias': 'HOU', 'yardline': 33},
#          'end_location': {'alias': 'HOU', 'yardline': 32},
#          'players': [{'id': 'bd01d907-cd57-48cb-9136-5692a4764a20',
#            'name': 'Chris Conley',
#            'jersey': '18',
#            'position': 'WR',
#            'sr_id': 'sr:player:834671',
#            'role': 'catch'}]},
#         {'category': 'fumble',
#          'description': 'C.Conley FUMBLES.',
#          'sequence': 2,
#          'start_location': {'alias': 'HOU', 'yardline': 32},
#          'end_location': {'alias': 'HOU', 'yardline': 47},
#          'players': [{'id': 'bd01d907-cd57-48cb-9136-5692a4764a20',
#            'name': 'Chris Conley',
#            'jersey': '18',
#            'position': 'WR',
#            'sr_id': 'sr:player:834671',
#            'role': 'fumble'}]},
#         {'category': 'opponent_fumble_recovery',
#          'description': 'Fumble RECOVERED by NE-M.Judon at HOU 47.',
#          'sequence': 3,
#          'start_location': {'alias': 'HOU', 'yardline': 47},
#          'end_location': {'alias': 'NE', 'yardline': 47},
#          'recovery': {'type': 'other_team',
#           'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#            'name': 'Patriots',
#            'market': 'New England',
#            'alias': 'NE',
#            'sr_id': 'sr:competitor:4424'}},
#          'players': [{'id': '99d79bb9-45aa-4c64-99aa-a92ba2c278af',
#            'name': 'Matt Judon',
#            'jersey': '09',
#            'position': 'LB',
#            'sr_id': 'sr:player:1074196',
#            'role': 'fum_rec'}]},
#         {'category': 'tackle',
#          'description': 'Tackled by at NE 47.',
#          'sequence': 4,
#          'start_location': {'alias': 'NE', 'yardline': 47},
#          'end_location': {'alias': 'NE', 'yardline': 47},
#          'players': []},
#         {'category': 'penalty',
#          'description': 'PENALTY on NE-J.Jackson, Defensive Illegal Blindside Block, 0 yards, accepted.',
#          'sequence': 5,
#          'start_location': {'alias': 'NE', 'yardline': 47},
#          'end_location': {'alias': 'NE', 'yardline': 47},
#          'penalty': {'description': 'Defensive Illegal Blindside Block',
#           'result': 'accepted',
#           'yards': 0,
#           'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#            'name': 'Patriots',
#            'market': 'New England',
#            'alias': 'NE',
#            'sr_id': 'sr:competitor:4424'}},
#          'players': [{'id': 'b590479c-79df-4505-be19-b0838574b434',
#            'name': 'J.C. Jackson',
#            'jersey': '27',
#            'position': 'DB',
#            'sr_id': 'sr:player:1474652',
#            'role': 'penalty'}]},
#         {'category': 'stat_correction',
#          'sequence': 6,
#          'start_location': {'alias': 'NE', 'yardline': 47},
#          'end_location': {'alias': 'NE', 'yardline': 47},
#          'players': []}]}]},
#     {'type': 'event',
#      'id': 'dfc5a2f0-2a04-11ec-834e-9dfff327683a',
#      'sequence': 1633896115051.0,
#      'clock': '00:00',
#      'event_type': 'game_over',
#      'description': 'End Game',
#      'created_at': '2021-10-10T20:01:55+00:00',
#      'updated_at': '2021-10-10T20:01:55+00:00',
#      'wall_clock': '2021-10-10T20:01:52+00:00'}]}],
#  '_comment': 'Generation started @ 2022-08-04 20:51:10 UTC ended @ 2022-08-04 20:51:11 UTC'}

# %%
data.keys()
# Out:
# dict_keys(['id', 'status', 'scheduled', 'attendance', 'entry_mode', 'clock', 'quarter', 'sr_id', 'weather', 'summary', 'periods', '_comment'])

# %%
quarters = data['periods']
first_quarter = quarters[0]
print(first_quarter['pbp'][0].keys())
play = first_quarter['pbp'][0]['events'][-2]
play
# Out:
# dict_keys(['type', 'id', 'sequence', 'start_reason', 'end_reason', 'play_count', 'duration', 'first_downs', 'gain', 'penalty_yards', 'inside_20', 'scoring_drive', 'created_at', 'updated_at', 'events'])
# {'type': 'play',
#  'id': 'dc630e70-29ed-11ec-834e-9dfff327683a',
#  'sequence': 1633886282834.0,
#  'clock': '4:58',
#  'home_points': 6,
#  'away_points': 0,
#  'play_type': 'pass',
#  'scoring_play': True,
#  'wall_clock': '2021-10-10T17:17:25+00:00',
#  'description': 'D.Mills pass short right complete to NE End Zone. Catch made by A.Auclair at NE End Zone. Gain of 11 yards. A.Auclair for 11 yards, TOUCHDOWN.',
#  'scoring_description': 'D.Mills pass short right complete to NE End Zone. Catch made by A.Auclair at NE End Zone. Gain of 11 yards. A.Auclair for 11 yards, TOUCHDOWN.',
#  'players_rushed': 6,
#  'men_in_box': 7,
#  'fake_punt': False,
#  'fake_field_goal': False,
#  'screen_pass': False,
#  'blitz': True,
#  'play_direction': 'Right',
#  'left_tightends': 1,
#  'right_tightends': 2,
#  'hash_mark': 'Left Hash',
#  'pocket_location': 'Middle',
#  'qb_at_snap': 'Under Center',
#  'huddle': 'Huddle',
#  'pass_route': 'Go',
#  'play_action': True,
#  'run_pass_option': False,
#  'created_at': '2021-10-10T17:18:02+00:00',
#  'updated_at': '2021-10-11T21:37:01+00:00',
#  'start_situation': {'clock': '4:58',
#   'down': 3,
#   'yfd': 1,
#   'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#    'name': 'Texans',
#    'market': 'Houston',
#    'alias': 'HOU',
#    'sr_id': 'sr:competitor:4324'},
#   'location': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#    'name': 'Patriots',
#    'market': 'New England',
#    'alias': 'NE',
#    'sr_id': 'sr:competitor:4424',
#    'yardline': 11}},
#  'end_situation': {'clock': '4:54',
#   'down': 0,
#   'yfd': 0,
#   'possession': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#    'name': 'Texans',
#    'market': 'Houston',
#    'alias': 'HOU',
#    'sr_id': 'sr:competitor:4324'},
#   'location': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#    'name': 'Patriots',
#    'market': 'New England',
#    'alias': 'NE',
#    'sr_id': 'sr:competitor:4424',
#    'yardline': 15}},
#  'score': {'sequence': 2,
#   'clock': '4:54',
#   'points': 6,
#   'home_points': 6,
#   'away_points': 0,
#   'points-after-play': {'id': '070499a0-29ee-11ec-834e-9dfff327683a',
#    'sequence': 1633886305657.0,
#    'type': 'extra_point'}},
#  'statistics': [{'stat_type': 'pass',
#    'attempt': 1,
#    'complete': 1,
#    'yards': 11,
#    'att_yards': 11,
#    'firstdown': 1,
#    'touchdown': 1,
#    'inside_20': 1,
#    'goaltogo': 0,
#    'blitz': 1,
#    'hurry': 0,
#    'knockdown': 0,
#    'pocket_time': 1.973,
#    'on_target_throw': 1,
#    'batted_pass': 0,
#    'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#     'name': 'Davis Mills',
#     'jersey': '10',
#     'position': 'QB',
#     'sr_id': 'sr:player:2197842'},
#    'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#     'name': 'Texans',
#     'market': 'Houston',
#     'alias': 'HOU',
#     'sr_id': 'sr:competitor:4324'}},
#   {'stat_type': 'receive',
#    'firstdown': 1,
#    'touchdown': 1,
#    'target': 1,
#    'reception': 1,
#    'yards': 11,
#    'yards_after_catch': 0,
#    'inside_20': 1,
#    'goaltogo': 0,
#    'broken_tackles': 0,
#    'dropped': 0,
#    'catchable': 0,
#    'yards_after_contact': 0,
#    'player': {'id': 'd6647491-8a3c-4f9f-999c-823823bd478d',
#     'name': 'Antony Auclair',
#     'jersey': '83',
#     'position': 'TE',
#     'sr_id': 'sr:player:1130991'},
#    'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#     'name': 'Texans',
#     'market': 'Houston',
#     'alias': 'HOU',
#     'sr_id': 'sr:competitor:4324'}},
#   {'stat_type': 'defense',
#    'missed_tackles': 0,
#    'def_target': 0,
#    'def_comp': 0,
#    'blitz': 1,
#    'hurry': 0,
#    'knockdown': 0,
#    'batted_pass': 0,
#    'player': {'id': '3164fc4b-b2ae-43b3-9ff1-1d5f744b9f88',
#     'name': "Ja'Whaun Bentley",
#     'jersey': '08',
#     'position': 'LB',
#     'sr_id': 'sr:player:1227326'},
#    'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#     'name': 'Patriots',
#     'market': 'New England',
#     'alias': 'NE',
#     'sr_id': 'sr:competitor:4424'}},
#   {'stat_type': 'defense',
#    'missed_tackles': 0,
#    'def_target': 1,
#    'def_comp': 1,
#    'blitz': 0,
#    'hurry': 0,
#    'knockdown': 0,
#    'batted_pass': 0,
#    'player': {'id': '1d8d5c04-15e7-4346-9d1f-f128e4df3adb',
#     'name': 'Kyle Dugger',
#     'jersey': '23',
#     'position': 'DB',
#     'sr_id': 'sr:player:2040541'},
#    'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#     'name': 'Patriots',
#     'market': 'New England',
#     'alias': 'NE',
#     'sr_id': 'sr:competitor:4424'}},
#   {'stat_type': 'defense',
#    'missed_tackles': 0,
#    'def_target': 0,
#    'def_comp': 0,
#    'blitz': 1,
#    'hurry': 0,
#    'knockdown': 0,
#    'batted_pass': 0,
#    'player': {'id': '99d79bb9-45aa-4c64-99aa-a92ba2c278af',
#     'name': 'Matt Judon',
#     'jersey': '09',
#     'position': 'LB',
#     'sr_id': 'sr:player:1074196'},
#    'team': {'id': '97354895-8c77-4fd4-a860-32e62ea7382a',
#     'name': 'Patriots',
#     'market': 'New England',
#     'alias': 'NE',
#     'sr_id': 'sr:competitor:4424'}},
#   {'stat_type': 'down_conversion',
#    'down': 3,
#    'attempt': 1,
#    'complete': 1,
#    'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#     'name': 'Texans',
#     'market': 'Houston',
#     'alias': 'HOU',
#     'sr_id': 'sr:competitor:4324'}},
#   {'stat_type': 'first_down',
#    'category': 'pass',
#    'player': {'id': 'd6647491-8a3c-4f9f-999c-823823bd478d',
#     'name': 'Antony Auclair',
#     'jersey': '83',
#     'position': 'TE',
#     'sr_id': 'sr:player:1130991'},
#    'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#     'name': 'Texans',
#     'market': 'Houston',
#     'alias': 'HOU',
#     'sr_id': 'sr:competitor:4324'}}],
#  'details': [{'category': 'pass_completion',
#    'description': 'D.Mills pass short right complete to NE End Zone.',
#    'sequence': 0,
#    'direction': 'short right',
#    'yards': 11,
#    'start_location': {'alias': 'NE', 'yardline': 11},
#    'end_location': {'alias': 'NE', 'yardline': 0},
#    'players': [{'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#      'name': 'Davis Mills',
#      'jersey': '10',
#      'position': 'QB',
#      'sr_id': 'sr:player:2197842',
#      'role': 'pass'}]},
#   {'category': 'pass_reception',
#    'description': 'Catch made by A.Auclair at NE End Zone. Gain of 11 yards.',
#    'sequence': 1,
#    'yards': 11,
#    'result': 'touchdown',
#    'start_location': {'alias': 'NE', 'yardline': 0},
#    'end_location': {'alias': 'NE', 'yardline': 0},
#    'players': [{'id': 'd6647491-8a3c-4f9f-999c-823823bd478d',
#      'name': 'Antony Auclair',
#      'jersey': '83',
#      'position': 'TE',
#      'sr_id': 'sr:player:1130991',
#      'role': 'catch'}]},
#   {'category': 'touchdown',
#    'description': 'A.Auclair for 11 yards, TOUCHDOWN.',
#    'sequence': 2,
#    'yards': 11,
#    'result': 'touchdown',
#    'start_location': {'alias': 'NE', 'yardline': 0},
#    'end_location': {'alias': 'NE', 'yardline': 0},
#    'players': [{'id': 'd6647491-8a3c-4f9f-999c-823823bd478d',
#      'name': 'Antony Auclair',
#      'jersey': '83',
#      'position': 'TE',
#      'sr_id': 'sr:player:1130991',
#      'role': 'catch'}]},
#   {'category': 'third_down_conversion',
#    'sequence': 3,
#    'result': 'good',
#    'start_location': {'alias': 'NE', 'yardline': 11},
#    'end_location': {'alias': 'NE', 'yardline': 11},
#    'players': []}]}

# %%
play.keys()
# Out:
# dict_keys(['type', 'id', 'sequence', 'clock', 'home_points', 'away_points', 'play_type', 'scoring_play', 'wall_clock', 'description', 'scoring_description', 'players_rushed', 'men_in_box', 'fake_punt', 'fake_field_goal', 'screen_pass', 'blitz', 'play_direction', 'left_tightends', 'right_tightends', 'hash_mark', 'pocket_location', 'qb_at_snap', 'huddle', 'pass_route', 'play_action', 'run_pass_option', 'created_at', 'updated_at', 'start_situation', 'end_situation', 'score', 'statistics', 'details'])

# %%
play['statistics'][0]
# Out:
# {'stat_type': 'pass',
#  'attempt': 1,
#  'complete': 1,
#  'yards': 11,
#  'att_yards': 11,
#  'firstdown': 1,
#  'touchdown': 1,
#  'inside_20': 1,
#  'goaltogo': 0,
#  'blitz': 1,
#  'hurry': 0,
#  'knockdown': 0,
#  'pocket_time': 1.973,
#  'on_target_throw': 1,
#  'batted_pass': 0,
#  'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10',
#   'name': 'Davis Mills',
#   'jersey': '10',
#   'position': 'QB',
#   'sr_id': 'sr:player:2197842'},
#  'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7',
#   'name': 'Texans',
#   'market': 'Houston',
#   'alias': 'HOU',
#   'sr_id': 'sr:competitor:4324'}}

# %%
completions = 0
attempts = 0
yards = 0
td = 0
for value in first_quarter['pbp'][0]['events']:
    if 'statistics' in value.keys():
        stat = value['statistics'][0]
        if stat['stat_type'] == 'pass':
            if 'nullified' not in stat.keys():
                completions += int(stat['complete'])
                attempts += int(stat['attempt'])
                if 'yards' in stat.keys():
                    yards += int(stat['yards'])
                if 'touchdown' in stat.keys():
                    td += 1
                print(stat)
                print()
        
print(f"Completions: {completions} - Attempts: {attempts} - Yards: {yards} - TD: {td}")
# Out:
# {'stat_type': 'pass', 'attempt': 1, 'complete': 0, 'att_yards': 0, 'firstdown': 0, 'inside_20': 0, 'goaltogo': 0, 'incompletion_type': 'Dropped Pass', 'blitz': 0, 'hurry': 0, 'knockdown': 0, 'pocket_time': 1.473, 'on_target_throw': 1, 'batted_pass': 0, 'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10', 'name': 'Davis Mills', 'jersey': '10', 'position': 'QB', 'sr_id': 'sr:player:2197842'}, 'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7', 'name': 'Texans', 'market': 'Houston', 'alias': 'HOU', 'sr_id': 'sr:competitor:4324'}}
#
# {'stat_type': 'pass', 'attempt': 1, 'complete': 1, 'yards': 8, 'att_yards': -2, 'firstdown': 0, 'inside_20': 0, 'goaltogo': 0, 'blitz': 1, 'hurry': 0, 'knockdown': 0, 'pocket_time': 0.922, 'on_target_throw': 1, 'batted_pass': 0, 'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10', 'name': 'Davis Mills', 'jersey': '10', 'position': 'QB', 'sr_id': 'sr:player:2197842'}, 'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7', 'name': 'Texans', 'market': 'Houston', 'alias': 'HOU', 'sr_id': 'sr:competitor:4324'}}
#
# {'stat_type': 'pass', 'attempt': 1, 'complete': 0, 'att_yards': 32, 'firstdown': 0, 'inside_20': 0, 'goaltogo': 0, 'incompletion_type': 'Poorly Thrown', 'blitz': 1, 'hurry': 0, 'knockdown': 1, 'pocket_time': 2.927, 'on_target_throw': 0, 'batted_pass': 0, 'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10', 'name': 'Davis Mills', 'jersey': '10', 'position': 'QB', 'sr_id': 'sr:player:2197842'}, 'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7', 'name': 'Texans', 'market': 'Houston', 'alias': 'HOU', 'sr_id': 'sr:competitor:4324'}}
#
# {'stat_type': 'pass', 'attempt': 1, 'complete': 1, 'yards': 8, 'att_yards': 5, 'firstdown': 1, 'inside_20': 0, 'goaltogo': 0, 'blitz': 1, 'hurry': 0, 'knockdown': 0, 'pocket_time': 0.883, 'on_target_throw': 1, 'batted_pass': 0, 'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10', 'name': 'Davis Mills', 'jersey': '10', 'position': 'QB', 'sr_id': 'sr:player:2197842'}, 'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7', 'name': 'Texans', 'market': 'Houston', 'alias': 'HOU', 'sr_id': 'sr:competitor:4324'}}
#
# {'stat_type': 'pass', 'attempt': 1, 'complete': 1, 'yards': 10, 'att_yards': -2, 'firstdown': 1, 'inside_20': 0, 'goaltogo': 0, 'blitz': 0, 'hurry': 0, 'knockdown': 0, 'pocket_time': 2.183, 'on_target_throw': 1, 'batted_pass': 0, 'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10', 'name': 'Davis Mills', 'jersey': '10', 'position': 'QB', 'sr_id': 'sr:player:2197842'}, 'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7', 'name': 'Texans', 'market': 'Houston', 'alias': 'HOU', 'sr_id': 'sr:competitor:4324'}}
#
# {'stat_type': 'pass', 'attempt': 1, 'complete': 1, 'yards': 7, 'att_yards': -4, 'firstdown': 0, 'inside_20': 1, 'goaltogo': 0, 'blitz': 0, 'hurry': 0, 'knockdown': 0, 'pocket_time': 0.333, 'on_target_throw': 1, 'batted_pass': 0, 'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10', 'name': 'Davis Mills', 'jersey': '10', 'position': 'QB', 'sr_id': 'sr:player:2197842'}, 'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7', 'name': 'Texans', 'market': 'Houston', 'alias': 'HOU', 'sr_id': 'sr:competitor:4324'}}
#
# {'stat_type': 'pass', 'attempt': 1, 'complete': 1, 'yards': 11, 'att_yards': 11, 'firstdown': 1, 'touchdown': 1, 'inside_20': 1, 'goaltogo': 0, 'blitz': 1, 'hurry': 0, 'knockdown': 0, 'pocket_time': 1.973, 'on_target_throw': 1, 'batted_pass': 0, 'player': {'id': '7d51fab7-2d52-4d19-a021-19a123af0d10', 'name': 'Davis Mills', 'jersey': '10', 'position': 'QB', 'sr_id': 'sr:player:2197842'}, 'team': {'id': '82d2d380-3834-4938-835f-aec541e5ece7', 'name': 'Texans', 'market': 'Houston', 'alias': 'HOU', 'sr_id': 'sr:competitor:4324'}}
#
# Completions: 5 - Attempts: 7 - Yards: 44 - TD: 1

# %%
def show_data(lst):
    i = 0
   
    while i < len(lst):
        
        x1, y1 = lst[i]
        
        if 'Attempt' in x1:
            x1 = x1[:-7]
            print(f"{x1} - 0/{y1}")
            i += 1
        elif 'Attempt' not in x1:
            x1, y1 = lst[i]
            x2, y2 = lst[i+1]
            print(f"{x1} - {y1}/{y2}")
            i += 2
        else:
            i += 1
                   
    print()
    
def show_plain_data(lst):
    for value in lst:
        x, y = value
        print(f"{x} - {y}")
    print()
    
#[('1 Long', 4), ('1 Long Attempt', 6), ('2 Long', 3), ('2 Long Attempt', 5), ('2 Medium', 2), ('2 Medium Attempt', 3), ('2 Short', 1), ('2 Short Attempt', 1), ('3 Long Attempt', 4), ('4 Long', 1), ('4 Long Attempt', 1), ('4 Short Attempt', 1)]

# %%
import json
from collections import defaultdict

completions = 0
attempts = 0
yards = 0
air_yards = 0
td = 0
interceptions = 0
sacks = 0
sack_yards = 0

players_rushed = defaultdict(int)
men_in_box = defaultdict(int)
qb_at_snap = defaultdict(int)
pass_route = defaultdict(int)
incompletion_type = defaultdict(int)
pass_type = defaultdict(int)
play_direction = defaultdict(int)
down_distance = defaultdict(int)

import json
from collections import defaultdict

f = open('../2021Games/game8.json')

data = json.load(f)

f.close()

for quarter in data['periods']: # Loop through all quarters
    for possession in quarter['pbp']: # Loop through all possessions
        if 'events' in possession.keys(): # Make sure possesion dict has events key
            for event in possession['events']: # Loop through every event of the possession
                if 'play_type' in event.keys() and event['play_type'] == 'pass': # make sure its a play and the play is a pass
                    if 'start_situation' in event.keys() and (event['start_situation']['possession']['alias'] == 'HOU'): # make sure Houston has possession
                        stat = None # Get the stat dict that will contain passing information
                        for statistics in event['statistics']:
                            if statistics['stat_type'] == 'pass':
                                stat = statistics
                                break
                                        
                        if 'nullified' not in stat.keys() and stat != None and stat['player']['name'] == "Davis Mills": # make sure there was no penalties
                            
        
                            down = event['start_situation']['down']
                            yfd = event['start_situation']['yfd']
                            
                            if 'sack_yards' in stat.keys():
                                sacks +=1
                                sack_yards += int(stat['sack_yards'])
                                
                            if 'complete' in stat.keys() and stat['complete'] == 1:
                                
                                if 'att_yards' in stat.keys():
                                    attempt_yards = int(stat['att_yards'])
                                
                                if 'play_direction' in event.keys():
                                    direction = str(event['play_direction'])
                                
                                air_yards += attempt_yards
                                completions += int(stat['complete'])
                                players_rushed[str(event['players_rushed'])] += 1
                                men_in_box[str(event['men_in_box'])] += 1
                                qb_at_snap[str(event['qb_at_snap'])] += 1
                                pass_route[str(event['pass_route'])] += 1
                                
                                if event['play_action']:
                                    pass_type['Play Action'] += 1
                                elif event['run_pass_option']:
                                    pass_type['RPO'] += 1
                                else:
                                    pass_type['Drop Back'] += 1
                                    
                                if int(yfd) <= 3:
                                    down_distance[str(down) + ' Short'] += 1
                                elif int(yfd) >= 8:
                                    down_distance[str(down) + ' Long'] += 1
                                else:
                                    down_distance[str(down) + ' Medium'] += 1
                                 
                                if attempt_yards <= 9:
                                    play_direction[direction + ' Short'] += 1
                                elif attempt_yards >= 21:
                                    play_direction[direction + ' Long'] += 1
                                else:
                                    play_direction[direction + ' Medium'] += 1     
                                
                            if 'attempt' in stat.keys():
                                
                                if 'att_yards' in stat.keys():
                                    attempt_yards = int(stat['att_yards'])
                                else:
                                    attempt_yards = "None"
                                    
                                if 'play_direction' in event.keys():
                                    direction = str(event['play_direction'])
                                else:
                                    direction = "None"
                                
                                attempts += int(stat['attempt'])
                                players_rushed[str(event['players_rushed']) + ' Attempt'] += 1
                                men_in_box[str(event['men_in_box']) + " Attempt"] += 1
                                qb_at_snap[str(event['qb_at_snap']) + " Attempt"] += 1
                                
                                if 'pass_route' in event.keys():
                                    pass_route[str(event['pass_route']) + " Attempt"] += 1
                                    
                                if event['play_action']:
                                    pass_type['Play Action Attempt'] += 1
                                elif event['run_pass_option']:
                                    pass_type['RPO Attempt'] += 1
                                else:
                                    pass_type['Drop Back Attempt'] += 1
                                    
                                if int(yfd) <= 3:
                                    down_distance[str(down) + ' Short Attempt'] += 1
                                elif int(yfd) >= 8:
                                    down_distance[str(down) + ' Long Attempt'] += 1
                                else:
                                    down_distance[str(down) + ' Medium Attempt'] += 1
                                
                                
                                if attempt_yards == "None":
                                    play_direction[direction + " Attempt"] += 1
                                elif attempt_yards <= 9:
                                    play_direction[direction + ' Short Attempt'] += 1
                                elif attempt_yards >= 21:
                                    play_direction[direction + ' Long Attempt'] += 1
                                else:
                                    play_direction[direction + ' Medium Attempt'] += 1    
                                
                            
                            if 'incompletion_type' in stat.keys():
                                incompletion_type[stat['incompletion_type']] += 1
                                
                            if 'yards' in stat.keys():
                                yards += int(stat['yards'])
                                
                            if 'touchdown' in stat.keys():
                                td += 1
                                
                            if 'interception' in stat.keys():
                                interceptions += 1
                            
                           
                            
                
players_rushed = sorted(players_rushed.items())
men_in_box = sorted(men_in_box.items())
qb_at_snap = sorted(qb_at_snap.items())
pass_route = sorted(pass_route.items())
incompletion_type = sorted(incompletion_type.items())
pass_type = sorted(pass_type.items())
play_direction = sorted(play_direction.items())
down_distance = sorted(down_distance.items())

comp_percent = (round(completions/attempts * 100,1)) if attempts != 0 else 0
air_to_yards = (round(air_yards/yards * 100,1)) if yards != 0 else 0
print(f"Completions: {completions} - Attempts: {attempts} - Completion %: {comp_percent}% - Air Yards: {air_yards} - Yards: {yards}  - Air/Passing Yards: {air_to_yards}% - TD: {td} - Int: {interceptions} - Sacks: {sacks}/{abs(sack_yards)}")
print()
print("Players Rushed - Completions/Attempts")
show_data(players_rushed)
print("Men in Box - Completions/Attempts")
show_data(men_in_box)
print("QB at Snap - Completions/Attempts")
show_data(qb_at_snap)
print("Route - Completions/Attempts")
show_data(pass_route)
print("Incompletion Types - Amount")
show_plain_data(incompletion_type)
print("Pass Type - Completions/Attempts")
show_data(pass_type)
print("Pass Direction - Completions/Attempts")
show_data(play_direction)
print("Down and Distance - Completions/Attempts")
show_data(down_distance)
# Out:
# Completions: 28 - Attempts: 37 - Completion %: 75.7% - Air Yards: 193 - Yards: 311  - Air/Passing Yards: 62.1% - TD: 2 - Int: 1 - Sacks: 5/31
#
# Players Rushed - Completions/Attempts
# 3 - 2/2
# 4 - 14/22
# 5 - 12/13
#
# Men in Box - Completions/Attempts
# 4 - 1/1
# 5 - 4/7
# 6 - 19/25
# 7 - 3/3
# 8 - 1/1
#
# QB at Snap - Completions/Attempts
# Shotgun - 24/33
# Under Center - 4/4
#
# Route - Completions/Attempts
# Comeback - 2/2
# Corner - 2/4
# Cross - 3/4
# Curl - 8/8
# Flat - 4/6
# Go - 1/2
# In - 1/1
# Out - 3/5
# Post - 2/2
# Underneath Screen - 2/2
#
# Incompletion Types - Amount
# Pass Defended - 3
# Poorly Thrown - 5
# Thrown Away - 1
#
# Pass Type - Completions/Attempts
# Drop Back - 23/32
# Play Action - 5/5
#
# Pass Direction - Completions/Attempts
# Left Short - 9/9
# Left Sideline Long - 3/3
# Left Sideline Medium  - 0/1
# Left Sideline Short - 6/10
# Middle Short - 1/1
# Right Long - 1/1
# Right Medium - 2/2
# Right Short - 2/2
# Right Sideline Long  - 0/1
# Right Sideline Medium - 1/1
# Right Sideline Short - 3/6
#
# Down and Distance - Completions/Attempts
# 1 Long - 11/17
# 2 Long - 7/8
# 2 Medium - 3/3
# 2 Short - 2/2
# 3 Long - 3/4
# 3 Medium  - 0/1
# 3 Short - 2/2

# %%
s = 'mmmmmmmm'
d = defaultdict(int)
for k in s:
    d[k] += 1
d
# Out:
# defaultdict(int,
#             {'n': 1, 'i': 1, 'c': 1, 'h': 1, 'o': 1, 'l': 1, 'a': 1, 's': 1})
